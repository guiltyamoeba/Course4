# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/91918/OneDrive/Desktop/SUDHEERA/DataScience with Gen Ai/Course4-Numpy python/Sprint3/DS1_C4_S3_SalesData_Practice.csv")
data
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 1    Jan     B  32985       Texas
# 2    Jan     C  22369  California
# 3    Jan     D  45710     Montana
# 4    Jan     E  27113  New Mexico
# 5    Feb     A  27573      Alaska
# 6    Feb     B  31244       Texas
# 7    Feb     C  48624  California
# 8    Feb     D  31768     Montana
# 9    Feb     E  23851  New Mexico
# 10   Mar     A  33274      Alaska
# 11   Mar     B  27215       Texas
# 12   Mar     C  23475  California
# 13   Mar     D  21357     Montana
# 14   Mar     E  22130  New Mexico
# 15   Apr     A  26073      Alaska
# 16   Apr     B  45919       Texas
# 17   Apr     C  30279  California
# 18   Apr     D  21394     Montana
# 19   Apr     E  25184  New Mexico
# 20   May     A  37649      Alaska
# 21   May     B  44597       Texas
# 22   May     C  29697  California
# 23   May     D  28943     Montana
# 24   May     E  22541  New Mexico
# 25   Jun     A  28500      Alaska
# ...

# %%
#Task1:
sort = data.sort_values("Sales", ascending = True)
sort
# Out:
#    Month Store  Sales       State
# 0    Jan     A  21080      Alaska
# 13   Mar     D  21357     Montana
# 18   Apr     D  21394     Montana
# 14   Mar     E  22130  New Mexico
# 2    Jan     C  22369  California
# 24   May     E  22541  New Mexico
# 12   Mar     C  23475  California
# 9    Feb     E  23851  New Mexico
# 19   Apr     E  25184  New Mexico
# 15   Apr     A  26073      Alaska
# 4    Jan     E  27113  New Mexico
# 11   Mar     B  27215       Texas
# 5    Feb     A  27573      Alaska
# 25   Jun     A  28500      Alaska
# 23   May     D  28943     Montana
# 22   May     C  29697  California
# 27   Jun     C  30200  California
# 17   Apr     C  30279  California
# 6    Feb     B  31244       Texas
# 8    Feb     D  31768     Montana
# 26   Jun     B  32896       Texas
# 1    Jan     B  32985       Texas
# 10   Mar     A  33274      Alaska
# 28   Jun     D  37098     Montana
# 20   May     A  37649      Alaska
# 29   Jun     E  41098  New Mexico
# ...

# %%
#Task2:
sales= data[(data.Sales >= 45000)]
sales
# Out:
#    Month Store  Sales       State
# 3    Jan     D  45710     Montana
# 7    Feb     C  48624  California
# 16   Apr     B  45919       Texas

# %%
#Task3:
#California
C = data[(data.State == 'California')]                         # Find sales entries for California
print("Total sales in California is:",C['Sales'])
california_sales = C.sort_values('Sales')
california_sales
# Out:
# Total sales in California is: 2     22369
# 7     48624
# 12    23475
# 17    30279
# 22    29697
# 27    30200
# Name: Sales, dtype: int64
#    Month Store  Sales       State
# 2    Jan     C  22369  California
# 12   Mar     C  23475  California
# 22   May     C  29697  California
# 27   Jun     C  30200  California
# 17   Apr     C  30279  California
# 7    Feb     C  48624  California

# %%
#Texas
T = data[(data.State == 'Texas')]                         # Find sales entries for California
print("Total sales in Texas is:",T['Sales'])
Texas_sales = T.sort_values('Sales')
Texas_sales
# Out:
# Total sales in Texas is: 1     32985
# 6     31244
# 11    27215
# 16    45919
# 21    44597
# 26    32896
# Name: Sales, dtype: int64
#    Month Store  Sales  State
# 11   Mar     B  27215  Texas
# 6    Feb     B  31244  Texas
# 26   Jun     B  32896  Texas
# 1    Jan     B  32985  Texas
# 21   May     B  44597  Texas
# 16   Apr     B  45919  Texas

# %%
#Montana
M = data[(data.State == 'Montana')]                         # Find sales entries for California
print("Total sales in Montana is:",M['Sales'])
Montana_sales = M.sort_values("Sales")
Montana_sales
# Out:
# Total sales in Montana is: 3     45710
# 8     31768
# 13    21357
# 18    21394
# 23    28943
# 28    37098
# Name: Sales, dtype: int64
#    Month Store  Sales    State
# 13   Mar     D  21357  Montana
# 18   Apr     D  21394  Montana
# 23   May     D  28943  Montana
# 8    Feb     D  31768  Montana
# 28   Jun     D  37098  Montana
# 3    Jan     D  45710  Montana

# %%
#Task4:
print("Total sales in the state of California is:",C['Sales'].sum())
print("Total sales in the state of Texas is:",T['Sales'].sum())
print("Total sales in the state of Montana is:",M['Sales'].sum())
# Out:
# Total sales in the state of California is: 184644
# Total sales in the state of Texas is: 214856
# Total sales in the state of Montana is: 186270

# %%
#TAsk5:
monthly_sales = california_sales.groupby('Month')['Sales'].sum().reset_index() #aggregation
highest_sales_month = monthly_sales.loc[monthly_sales['Sales'].idxmax()] #find maxsales
lowest_sales_month = monthly_sales.loc[monthly_sales['Sales'].idxmin()] #find minsales

print(f"In the {highest_sales_month['Month']} month the total_sales in California is: {highest_sales_month['Sales']}")
print(f"this is the highest sale for month wise sales")

print(f"In the {lowest_sales_month['Month']} month the total_sales in California is: {lowest_sales_month['Sales']}")
print(f"this is the lowest sale for month wise sales")
# Out:
# In the Feb month the total_sales in California is: 48624
# this is the highest sale for month wise sales
# In the Jan month the total_sales in California is: 22369
# this is the lowest sale for month wise sales

# %%
#Task6:
List = [['Alaska',174149],['Texas',214856],['California',184644],['Montana',186270],['New Maxico',161917]]
DF = pd.DataFrame(List, columns = ["State","Sale in thousands"])
print(DF)
# Out:
#         State  Sale in thousands
# 0      Alaska             174149
# 1       Texas             214856
# 2  California             184644
# 3     Montana             186270
# 4  New Maxico             161917

# %%
#Task7:
DF.to_csv("file.csv")

# %%
DF.to_csv("file.csv")
DF
# Out:
#         State  Sale in thousands
# 0      Alaska             174149
# 1       Texas             214856
# 2  California             184644
# 3     Montana             186270
# 4  New Maxico             161917
